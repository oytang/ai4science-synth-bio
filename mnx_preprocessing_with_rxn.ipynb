# %% [markdown]
# # MetaNetX data preprocessing
#
# Correlate `reac_prop.tsv` and `chem_prop.tsv` to convert dataset into useful format (SMILES, InChI or InChiKey).
#
# Two methods, one simpler and one more comprehensive.
#
# 1. Discard all reaction information and get a list of metabolites involved in reaction to be seen as "bioreachable".
# 2. Retain all reaction information but change MNX_ID's into useful chemical representations.

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm, trange

# %%
reac = pd.read_csv('reac_clean.csv')
for col in ['metabolites', 'substrates', 'products']:
    reac[col] = reac[col].apply(eval)
reac
# Out:
#               #ID                                       mnx_equation  \
# 0           EMPTY                                                 =
# 1          MNXR01                     1 MNXM01@MNXD1 = 1 MNXM1@MNXD1
# 2          MNXR02                      1 MNXM1@MNXD1 = 1 MNXM1@MNXD2
# 3          MNXR03                    1 MNXM01@MNXD1 = 1 MNXM01@MNXD2
# 4      MNXR100000  1 MNXM10958@MNXD1 + 1 MNXM1104529@MNXD1 = 1 MN...
# ...           ...                                                ...
# 74608   MNXR99995  1 MNXM1100890@MNXD1 + 1 MNXM147451@MNXD1 = 1 M...
# 74609   MNXR99996  1 MNXM1100890@MNXD1 + 1 MNXM163780@MNXD1 = 1 M...
# 74610   MNXR99997  1 MNXM1102128@MNXD1 + 1 MNXM147449@MNXD1 = 1 M...
# 74611   MNXR99998  1 MNXM10945@MNXD1 + 1 MNXM1104529@MNXD1 = 1 MN...
# 74612   MNXR99999  1 MNXM10951@MNXD1 + 1 MNXM1104529@MNXD1 = 1 MN...
#
#                                                 equation  \
# 0                                                     =
# ...

# %%
chem = pd.read_csv('mnx_chem_bioreachable.csv')
chem
# Out:
#              #ID                                       name  \
# 0         MNXM01                                        PMF
# 1          MNXM1                                       H(+)
# 2         MNXM10                                       NADH
# 3        MNXM100                   (2E)-geranyl diphosphate
# 4      MNXM10002                           3-deoxycapsidiol
# ...          ...                                        ...
# 42547   MNXM9994              5-chlorobenzoate-cis-3,4-diol
# 42548   MNXM9995                            3-chlorotoluene
# 42549  MNXM99969                           compound 0043171
# 42550   MNXM9999                      3-demethylubiquinol-7
# 42551  MNXM99992  (9Z,11E)-tetradeca-9,11-dien-1-yl acetate
#
#                                                reference        formula  \
# 0                                                mnx:PMF              H
# 1                                             mnx:PROTON              H
# ...

# %% [markdown]
# ## Retaining RXN info
#
# ### Removing reactions involving missing values

# %%
def findIdentifier(mnxid_list, identifier):

    mnxid = chem[chem['#ID'].isin(mnxid_list)][identifier]
    
    # missing value found
    if mnxid.isna().sum() > 0:
        return None
    
    # all SMILES are valid
    else:
        return mnxid.values.tolist()

def findIdRxn(reac, i, identifier):
    substrates = findIdentifier(reac.loc[i, 'substrates'], identifier)
    products = findIdentifier(reac.loc[i, 'products'], identifier)

    # not meaningful chemically
    if substrates == products:
        return None, None

    return substrates, products

# %%
substrates_identifiers = []
products_identifiers = []
for i in trange(len(reac)):

    substrates, products = findIdRxn(reac, i, 'SMILES')

    if substrates is None or products is None:
        substrates_identifiers.append(None)
        products_identifiers.append(None)
    else:
        substrates_identifiers.append(substrates)
        products_identifiers.append(products)

reac['substrates_SMILES'] = substrates_identifiers
reac['products_SMILES'] = products_identifiers
# Out:
# 100%|██████████| 74613/74613 [05:04<00:00, 244.99it/s]

# %%
reac_nona = reac.dropna(subset=['substrates_SMILES', 'products_SMILES'])
reac_nona
# Out:
#               #ID                                       mnx_equation  \
# 10     MNXR100011  1 MNXM1108175@MNXD1 + 1 MNXM1@MNXD1 + 2 MNXM27...
# 13     MNXR100018  1 MNXM1233@MNXD1 + 1 MNXM73@MNXD2 = 1 MNXM23@M...
# 15     MNXR100024  1 MNXM1@MNXD1 + 1 MNXM37@MNXD1 + 1 MNXM40333@M...
# 19     MNXR100030  1 MNXM37@MNXD1 + 1 WATER@MNXD1 = 1 MNXM729302@...
# 21     MNXR100036  1 MNXM1104266@MNXD1 + 1 MNXM6274@MNXD1 = 1 MNX...
# ...           ...                                                ...
# 74580   MNXR99957  1 MNXM1627@MNXD1 + 1 WATER@MNXD1 = 1 MNXM1734@...
# 74595   MNXR99976  1 MNXM1100890@MNXD1 + 1 MNXM1105733@MNXD1 = 1 ...
# 74597   MNXR99978  1 MNXM1100890@MNXD1 + 1 MNXM8636@MNXD1 = 1 MNX...
# 74599   MNXR99980  1 MNXM1100890@MNXD1 + 1 MNXM6274@MNXD1 = 1 MNX...
# 74600   MNXR99982  1 MNXM1100890@MNXD1 + 1 MNXM7406@MNXD1 = 1 MNX...
#
#                                                 equation  \
# 10     1 MNXM1108175 + 1 MNXM1 + 2 MNXM27 + 1 MNXM403...
# ...

# %%
print(f'total rxn: {len(reac)}')
print(f'incomplete or meaningless rxn: {len(reac) - len(reac_nona)}')
print(f'available rxn: {len(reac_nona)}')
# Out:
# total rxn: 74613
# incomplete or meaningless rxn: 28187
# available rxn: 46426

# %%
reac_nona = reac_nona[['#ID', 'equation', 'substrates_SMILES', 'products_SMILES']]
reac_nona
# Out:
#               #ID                                           equation  \
# 10     MNXR100011  1 MNXM1108175 + 1 MNXM1 + 2 MNXM27 + 1 MNXM403...
# 13     MNXR100018    1 MNXM1233 + 1 MNXM73 = 1 MNXM23 + 1 MNXM731248
# 15     MNXR100024  1 MNXM1 + 1 MNXM37 + 1 MNXM40333 + 1 MNXM9 = 1...
# 19     MNXR100030   1 MNXM37 + 1 WATER = 1 MNXM729302 + 1 MNXM741173
# 21     MNXR100036  1 MNXM1104266 + 1 MNXM6274 = 1 MNXM6987 + 1 MN...
# ...           ...                                                ...
# 74580   MNXR99957                  1 MNXM1627 + 1 WATER = 1 MNXM1734
# 74595   MNXR99976  1 MNXM1100890 + 1 MNXM1105733 = 1 MNXM1102128 ...
# 74597   MNXR99978  1 MNXM1100890 + 1 MNXM8636 = 1 MNXM1102128 + 1...
# 74599   MNXR99980  1 MNXM1100890 + 1 MNXM6274 = 1 MNXM1102128 + 1...
# 74600   MNXR99982  1 MNXM1100890 + 1 MNXM7406 = 1 MNXM1102128 + 1...
#
#                                        substrates_SMILES  \
# 10     [[H+], OC[C@H]1O[C@H](O)[C@H](O)[C@@H](O)[C@H]...
# ...

# %%
reac_nona.to_csv('mnx_reac_bioreachable.csv', index=False)
